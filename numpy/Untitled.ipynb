# %%
import numpy as np

# %% [markdown]
# # NUMPY

# %% [markdown]
# # numpy.random()

# %%
print(np.linspace(1,10,num=5,endpoint=True,retstep=True))
# Out:
# (array([ 1.  ,  3.25,  5.5 ,  7.75, 10.  ]), 2.25)

# %% [markdown]
# ## np.linspace(1,10,num=5)
#           where it produce numpy array having value b/w 1 to 10 havingsize (2,5)

# %% [markdown]
# # standard deviation and normal distribution
#
# ## noise=np.random.randn(2,5) generate sample from normal distribution
# ## np.random.rand(2) genrate output between [0 ,1).  gives two output
# ## noise=np.random.uniform(1,9,10) output the array vector with 10 element between 1,9

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # for random go to https://pynative.com/python-get-random-float-numbers/

# %% [markdown]
# # ->-> numpy array

# %%
a=np.array(((1,2,3),(2,5,6)))

# %% [markdown]
# https://thispointer.com/python-numpy-create-a-ndarray-from-list-tuple-or-list-of-lists-using-numpy-array/

# %%
a
# Out:
# array([[1, 2, 3],
#        [2, 5, 6]])

# %%
a.ndim # give dimension
# Out:
# 2

# %%
a.dtype
# Out:
# dtype('int32')

# %%
type(a)  #gives class name
# Out:
# numpy.ndarray

# %%
a.size #gives the total no. of element
# Out:
# 6

# %%
a.shape #gives the shape of array
# Out:
# (2, 3)

# %%
a.reshape(3,2)  # use to transpose the numpy array i.e row become column and vice versa
# Out:
# array([[1, 2],
#        [3, 2],
#        [5, 6]])

# %%
a[0:,1] #slicing
# Out:
# array([2, 5])
